# %% [markdown]
# # Diffie-Hellman Protocol

# %% [markdown]
# Thêm các thư viện cần thiết

# %%
import random

# %% [markdown]
# Căn nguyên thủy là số sinh ra được tất cả các số trong Z (các số đồng nguyên tố), ví dụ đồng dư 14 có căn nguyên thủy là 3 và 5
#
# Các số 1, 2, 4, p^k, 2*p^k

# %% [markdown]
# Hàm khởi tạo căn nguyên thủy
